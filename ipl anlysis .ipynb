# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\Users\91948\Desktop\python\python project using ipl dataset\matches - matches (1).csv")
df.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
df.shape  # to see the shape of the data
# Out:
# (636, 18)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 636 entries, 0 to 635
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               636 non-null    int64
#  1   season           636 non-null    int64
#  2   city             629 non-null    object
#  3   date             636 non-null    object
#  4   team1            636 non-null    object
#  5   team2            636 non-null    object
#  6   toss_winner      636 non-null    object
#  7   toss_decision    636 non-null    object
#  8   result           636 non-null    object
#  9   dl_applied       636 non-null    int64
#  10  winner           633 non-null    object
#  11  win_by_runs      636 non-null    int64
#  12  win_by_wickets   636 non-null    int64
#  13  player_of_match  633 non-null    object
#  14  venue            636 non-null    object
#  15  umpire1          635 non-null    object
#  16  umpire2          635 non-null    object
# ...

# %%
data.describe()
# Out:
#                id       season  dl_applied  win_by_runs  win_by_wickets  \
# count  636.000000   636.000000  636.000000   636.000000      636.000000
# mean   318.500000  2012.490566    0.025157    13.682390        3.372642
# std    183.741666     2.773026    0.156726    23.908877        3.420338
# min      1.000000  2008.000000    0.000000     0.000000        0.000000
# 25%    159.750000  2010.000000    0.000000     0.000000        0.000000
# 50%    318.500000  2012.000000    0.000000     0.000000        4.000000
# 75%    477.250000  2015.000000    0.000000    20.000000        7.000000
# max    636.000000  2017.000000    1.000000   146.000000       10.000000
#
#        umpire3
# count      0.0
# mean       NaN
# std        NaN
# min        NaN
# 25%        NaN
# 50%        NaN
# 75%        NaN
# max        NaN

# %%
 df['winner'].shape
# Out:
# (636,)

# %%
df[['team1','team2','winner']]
# Out:
#                            team1                        team2  \
# 0            Sunrisers Hyderabad  Royal Challengers Bangalore
# 1                 Mumbai Indians       Rising Pune Supergiant
# 2                  Gujarat Lions        Kolkata Knight Riders
# 3         Rising Pune Supergiant              Kings XI Punjab
# 4    Royal Challengers Bangalore             Delhi Daredevils
# ..                           ...                          ...
# 631             Delhi Daredevils  Royal Challengers Bangalore
# 632                Gujarat Lions  Royal Challengers Bangalore
# 633          Sunrisers Hyderabad        Kolkata Knight Riders
# 634                Gujarat Lions          Sunrisers Hyderabad
# 635          Sunrisers Hyderabad  Royal Challengers Bangalore
#
#                           winner
# 0            Sunrisers Hyderabad
# 1         Rising Pune Supergiant
# 2          Kolkata Knight Riders
# 3                Kings XI Punjab
# 4    Royal Challengers Bangalore
# ...

# %%
df.iloc[1:11:6]
# Out:
#    id  season    city        date                        team1  \
# 1   2    2017    Pune  2017-04-06               Mumbai Indians
# 7   8    2017  Indore  2017-04-10  Royal Challengers Bangalore
#
#                     team2                  toss_winner toss_decision  result  \
# 1  Rising Pune Supergiant       Rising Pune Supergiant         field  normal
# 7         Kings XI Punjab  Royal Challengers Bangalore           bat  normal
#
#    dl_applied                  winner  win_by_runs  win_by_wickets  \
# 1           0  Rising Pune Supergiant            0               7
# 7           0         Kings XI Punjab            0               8
#
#   player_of_match                                    venue         umpire1  \
# 1       SPD Smith  Maharashtra Cricket Association Stadium  A Nand Kishore
# 7        AR Patel                   Holkar Cricket Stadium    AK Chaudhary
#
#          umpire2  umpire3
# 1         S Ravi      NaN
# 7  C Shamshuddin      NaN

# %%
df['city']=='bangalore'
df
# Out:
#       id  season       city        date                        team1  \
# 0      1    2017  bangalore  2017-04-05          Sunrisers Hyderabad
# 1      2    2017  bangalore  2017-04-06               Mumbai Indians
# 2      3    2017  bangalore  2017-04-07                Gujarat Lions
# 3      4    2017  bangalore  2017-04-08       Rising Pune Supergiant
# 4      5    2017  bangalore  2017-04-08  Royal Challengers Bangalore
# ..   ...     ...        ...         ...                          ...
# 631  632    2016  bangalore  2016-05-22             Delhi Daredevils
# 632  633    2016  bangalore  2016-05-24                Gujarat Lions
# 633  634    2016  bangalore  2016-05-25          Sunrisers Hyderabad
# 634  635    2016  bangalore  2016-05-27                Gujarat Lions
# 635  636    2016  bangalore  2016-05-29          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %% [markdown]
# # if you want particular details such as ex: fetch the detatiles match took place in hyderbad after 2010-1-1
# here yoy can use the function mask

# %%
mask1= df['city']=='Hyderabad'
mask2=df['date']>'2010-01-01'
df[mask1 & mask2]
df[mask1 & mask2].shape[0]
# Out:
# 521

# %% [markdown]
# # value counts function

# %%
# this is applicable to catgorical data not to numerical data

# %%
df['winner'].value_counts()
# Out:
# Mumbai Indians                 92
# Chennai Super Kings            79
# Kolkata Knight Riders          77
# Royal Challengers Bangalore    73
# Kings XI Punjab                70
# Rajasthan Royals               63
# Delhi Daredevils               62
# Sunrisers Hyderabad            42
# Deccan Chargers                29
# Gujarat Lions                  13
# Pune Warriors                  12
# Rising Pune Supergiant         10
# Kochi Tuskers Kerala            6
# Rising Pune Supergiants         5
# Name: winner, dtype: int64

# %% [markdown]
# # pandas plot

# %%
#‘line’ : line plot (default)

#‘bar’ : vertical bar plot

#‘barh’ : horizontal bar plot

#‘hist’ : histogram

#‘box’ : boxplot

#‘kde’ : Kernel Density Estimation plot

#‘density’ : same as ‘kde’

#‘area’ : area plot

#‘pie’ : pie plot

#‘scatter’ : scatter plot (DataFrame only)
 ## this are the some of the plot

# %%
df['winner'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df['toss_decision'].value_counts().plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='toss_decision'>

# %%
# you can create different visulisation type based upon data

# %%
df['toss_winner'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # series function

# %%
# index must be unique and value can be repeated

# %%
myseries=df['winner'].value_counts()
myseries
# Out:
# Mumbai Indians                 92
# Chennai Super Kings            79
# Kolkata Knight Riders          77
# Royal Challengers Bangalore    73
# Kings XI Punjab                70
# Rajasthan Royals               63
# Delhi Daredevils               62
# Sunrisers Hyderabad            42
# Deccan Chargers                29
# Gujarat Lions                  13
# Pune Warriors                  12
# Rising Pune Supergiant         10
# Kochi Tuskers Kerala            6
# Rising Pune Supergiants         5
# Name: winner, dtype: int64

# %%
myseries['Pune Warriors'] # here you will get exact matches played by one team through series function
# Out:
# 12

# %% [markdown]
# # sort values method

# %%
df.sort_values('city',ascending=False,inplace=True)  #this function is used to acertain value in ascending or descending 
df
# Out:
#       id  season       city        date                        team1  \
# 0      1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 7      8    2017  Hyderabad  2017-04-10  Royal Challengers Bangalore
# 10    11    2017  Hyderabad  2017-04-13              Kings XI Punjab
# 9     10    2017  Hyderabad  2017-04-12          Sunrisers Hyderabad
# 2      3    2017  Hyderabad  2017-04-07                Gujarat Lions
# ..   ...     ...        ...         ...                          ...
# 617  618    2016  Hyderabad  2016-05-12          Sunrisers Hyderabad
# 628  629    2016  Hyderabad  2016-05-21              Kings XI Punjab
# 629  630    2016  Hyderabad  2016-05-21               Mumbai Indians
# 630  631    2016  Hyderabad  2016-05-22        Kolkata Knight Riders
# 635  636    2016  Hyderabad  2016-05-29          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %% [markdown]
# # DROP DUPLICATES

# %%
# duplicate function converts dupliactes into unique values

# %%
# seeing the result of only final match excluding rest of the mqatch

# %%
df.drop_duplicates('season',keep='last')[['season','winner']].sort_values('season')
# Out:
#      season                 winner
# 116    2008       Rajasthan Royals
# 173    2009        Deccan Chargers
# 233    2010    Chennai Super Kings
# 306    2011    Chennai Super Kings
# 380    2012  Kolkata Knight Riders
# 456    2013         Mumbai Indians
# 516    2014  Kolkata Knight Riders
# 575    2015         Mumbai Indians
# 635    2016    Sunrisers Hyderabad
# 58     2017         Mumbai Indians

# %%
pwd
# Out:
# 'C:\\Users\\91948'
